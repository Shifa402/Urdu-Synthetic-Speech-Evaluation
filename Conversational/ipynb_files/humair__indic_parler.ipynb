# %%
# !pip install "datasets<3.0.0" soundfile transformers accelerate torch resemblyzer librosa pandas scipy
# Out:
# Requirement already satisfied: datasets<3.0.0 in /usr/local/lib/python3.12/dist-packages (2.21.0)
# Requirement already satisfied: soundfile in /usr/local/lib/python3.12/dist-packages (0.13.1)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (4.46.1)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.12/dist-packages (1.13.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.10.0+cu128)
# Requirement already satisfied: resemblyzer in /usr/local/lib/python3.12/dist-packages (0.1.4)
# Requirement already satisfied: librosa in /usr/local/lib/python3.12/dist-packages (0.11.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (1.16.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets<3.0.0) (3.25.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from datasets<3.0.0) (2.0.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets<3.0.0) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets<3.0.0) (0.3.8)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets<3.0.0) (2.32.4)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.12/dist-packages (from datasets<3.0.0) (4.67.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets<3.0.0) (3.6.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.12/dist-packages (from datasets<3.0.0) (0.70.16)
# Requirement already satisfied: fsspec<=2024.6.1,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2024.6.1,>=2023.1.0->datasets<3.0.0) (2024.6.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.12/dist-packages (from datasets<3.0.0) (3.13.5)
# Requirement already satisfied: huggingface-hub>=0.21.2 in /usr/local/lib/python3.12/dist-packages (from datasets<3.0.0) (0.36.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from datasets<3.0.0) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from datasets<3.0.0) (6.0.3)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.12/dist-packages (from soundfile) (2.0.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2025.11.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.7.0)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.20.3)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch) (1.5.2)
# Requirement already satisfied: webrtcvad>=2.0.10 in /usr/local/lib/python3.12/dist-packages (from resemblyzer) (2.0.10)
# Requirement already satisfied: typing in /usr/local/lib/python3.12/dist-packages (from resemblyzer) (3.7.4.3)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.12/dist-packages (from librosa) (3.1.0)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.12/dist-packages (from librosa) (0.60.0)
# Requirement already satisfied: scikit-learn>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from librosa) (1.6.1)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.12/dist-packages (from librosa) (1.5.3)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from librosa) (4.4.2)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.12/dist-packages (from librosa) (1.9.0)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.12/dist-packages (from librosa) (1.0.0)
# Requirement already satisfied: lazy_loader>=0.1 in /usr/local/lib/python3.12/dist-packages (from librosa) (0.5)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.12/dist-packages (from librosa) (1.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2026.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0->soundfile) (3.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets<3.0.0) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets<3.0.0) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets<3.0.0) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets<3.0.0) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets<3.0.0) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets<3.0.0) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets<3.0.0) (1.23.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.21.2->datasets<3.0.0) (1.4.3)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.51.0->librosa) (0.43.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from pooch>=1.1->librosa) (4.9.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets<3.0.0) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets<3.0.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets<3.0.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets<3.0.0) (2026.2.25)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.1.0->librosa) (3.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.3)

# %%
# !pip install protobuf==4.25.9
# Out:
# Requirement already satisfied: protobuf==4.25.9 in /usr/local/lib/python3.12/dist-packages (4.25.9)

# %%
# !pip install --upgrade sympy
# Out:
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (1.14.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy) (1.3.0)

# %%
# !pip install -q parler_tts

# %%
import torch
import numpy as np
import pandas as pd
import soundfile as sf
import os
from pathlib import Path
from resemblyzer import VoiceEncoder, preprocess_wav

# ================== NEW: Indic-Parler-TTS Imports & Config ==================
from parler_tts import ParlerTTSForConditionalGeneration
from transformers import AutoTokenizer

# ── Config ─────────────────────────────────────────────────────
MODEL_NAME = "ai4bharat/indic-parler-tts"
device = "cuda" if torch.cuda.is_available() else "cpu"

# ── Load Indic-Parler-TTS (male Urdu voice: Rohit) ─────────────
print(f"Loading Indic-Parler-TTS model to {device}... (this may take 1-2 minutes first time)")

model = ParlerTTSForConditionalGeneration.from_pretrained(MODEL_NAME).to(device)
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
description_tokenizer = AutoTokenizer.from_pretrained(model.config.text_encoder._name_or_path)

encoder = VoiceEncoder()

# Fixed male Urdu description using "Rohit" (best consistency + naturalness)
MALE_URDU_DESCRIPTION = (
    "Rohit's voice is clear and natural with a moderate speed and pitch. "
    "The recording is of very high quality, with the speaker's voice sounding very close up "
    "and no background noise."
)

print("✅ Indic-Parler-TTS loaded successfully (male Urdu voice: Rohit)")

def run_evaluation(dataset_name, samples_list, text_key, limit):
    """Generate TTS using Indic-Parler-TTS and compute Resemblyzer similarities."""
    base_dir = f"mushra_{dataset_name}"
    # Keeping the requested subfolders
    for sub in ["reference", "generated", "anchor"]:
        os.makedirs(f"{base_dir}/{sub}", exist_ok=True)

    results = []
    for i, sample in enumerate(samples_list[:limit]):
        try:
            text = sample[text_key]
            ref_array = np.array(sample["audio"]["array"]).astype(np.float32)
            ref_sr = sample["audio"]["sampling_rate"]
            if ref_array.ndim > 1:
                ref_array = ref_array.mean(axis=1)

            ref_path = f"{base_dir}/reference/sample_{i}.wav"
            gen_path = f"{base_dir}/generated/sample_{i}.wav"

            # 1. Reference
            sf.write(ref_path, ref_array, ref_sr)

            # ================== NEW: Indic-Parler-TTS Generation ==================
            description_input_ids = description_tokenizer(
                MALE_URDU_DESCRIPTION, return_tensors="pt"
            ).to(device)
            prompt_input_ids = tokenizer(text, return_tensors="pt").to(device)

            with torch.no_grad():
                generation = model.generate(
                    input_ids=description_input_ids.input_ids,
                    attention_mask=description_input_ids.attention_mask,
                    prompt_input_ids=prompt_input_ids.input_ids,
                    prompt_attention_mask=prompt_input_ids.attention_mask,
                    do_sample=True,          # better naturalness
                    temperature=0.8
                )

            gen_speech = generation.cpu().numpy().squeeze()
            gen_sr = model.config.sampling_rate
            sf.write(gen_path, gen_speech, gen_sr)

            # 3. Resemblyzer embeddings (Unchanged)
            ref_wav = preprocess_wav(Path(ref_path))
            gen_wav = preprocess_wav(Path(gen_path))
            ref_emb = encoder.embed_utterance(ref_wav)
            gen_emb = encoder.embed_utterance(gen_wav)

            # Using cosine similarity formula from provided example
            ref_gen_sim = np.dot(ref_emb, gen_emb) / (np.linalg.norm(ref_emb) * np.linalg.norm(gen_emb))

            results.append({
                "sample_id": i,
                "urdu_text": text,
                "gender": sample.get("gender", "N/A"),
                "audio_duration_sec": round(len(ref_array) / ref_sr, 2),
                "ref_gen_similarity": round(float(ref_gen_sim), 4),
            })
            print(f"  [{i+1:02d}/{limit}] sim={ref_gen_sim:.4f} gender={sample.get('gender')} text={text[:30]}...")
        except Exception as e:
            print(f"  ☑ Sample {i} failed: {e}")

    print(f"\n✅ {dataset_name}: {len(results)}/{limit} samples evaluated")
    return results
# Out:
# Loading Indic-Parler-TTS model to cuda... (this may take 1-2 minutes first time)
# WARNING:parler_tts.modeling_parler_tts:Config of the text_encoder: <class 'transformers.models.t5.modeling_t5.T5EncoderModel'> is overwritten by shared text_encoder config: T5Config {
#   "_name_or_path": "google/flan-t5-large",
#   "architectures": [
#     "T5ForConditionalGeneration"
#   ],
#   "classifier_dropout": 0.0,
#   "d_ff": 2816,
#   "d_kv": 64,
#   "d_model": 1024,
#   "decoder_start_token_id": 0,
#   "dense_act_fn": "gelu_new",
#   "dropout_rate": 0.1,
#   "eos_token_id": 1,
#   "feed_forward_proj": "gated-gelu",
#   "initializer_factor": 1.0,
#   "is_encoder_decoder": true,
#   "is_gated_act": true,
#   "layer_norm_epsilon": 1e-06,
#   "model_type": "t5",
#   "n_positions": 512,
#   "num_decoder_layers": 24,
#   "num_heads": 16,
#   "num_layers": 24,
#   "output_past": true,
#   "pad_token_id": 0,
#   "relative_attention_max_distance": 128,
#   "relative_attention_num_buckets": 32,
#   "tie_word_embeddings": false,
#   "transformers_version": "4.46.1",
#   "use_cache": true,
#   "vocab_size": 32128
# }
#
# WARNING:parler_tts.modeling_parler_tts:Config of the audio_encoder: <class 'transformers.models.dac.modeling_dac.DacModel'> is overwritten by shared audio_encoder config: DacConfig {
#   "_name_or_path": "ylacombe/dac_44khz",
#   "architectures": [
#     "DacModel"
#   ],
#   "codebook_dim": 8,
#   "codebook_loss_weight": 1.0,
#   "codebook_size": 1024,
#   "commitment_loss_weight": 0.25,
#   "decoder_hidden_size": 1536,
#   "downsampling_ratios": [
#     2,
#     4,
#     8,
#     8
#   ],
#   "encoder_hidden_size": 64,
#   "hidden_size": 1024,
#   "hop_length": 512,
#   "model_type": "dac",
#   "n_codebooks": 9,
#   "quantizer_dropout": 0.0,
#   "sampling_rate": 44100,
#   "torch_dtype": "float32",
#   "transformers_version": "4.46.1",
#   "upsampling_ratios": [
#     8,
#     8,
#     4,
#     2
#   ]
# }
#
# WARNING:parler_tts.modeling_parler_tts:Config of the decoder: <class 'parler_tts.modeling_parler_tts.ParlerTTSForCausalLM'> is overwritten by shared decoder config: ParlerTTSDecoderConfig {
#   "_name_or_path": "/fsx/yoach/tmp/artefacts/parler-tts-mini-v2-empty/decoder",
#   "activation_dropout": 0.0,
#   "activation_function": "gelu",
#   "add_cross_attention": true,
#   "architectures": [
#     "ParlerTTSForCausalLM"
#   ],
#   "attention_dropout": 0.0,
#   "bos_token_id": 1025,
#   "codebook_weights": null,
#   "cross_attention_implementation_strategy": null,
#   "delay_strategy": "delay",
#   "dropout": 0.1,
#   "eos_token_id": 1024,
#   "ffn_dim": 4096,
#   "hidden_size": 1024,
#   "initializer_factor": 0.02,
#   "is_decoder": true,
#   "layerdrop": 0.0,
#   "max_position_embeddings": 4096,
#   "model_type": "parler_tts_decoder",
#   "num_attention_heads": 16,
#   "num_codebooks": 9,
#   "num_cross_attention_key_value_heads": 16,
#   "num_hidden_layers": 24,
#   "num_key_value_heads": 16,
#   "pad_token_id": 1024,
#   "rope_embeddings": false,
#   "rope_theta": 10000.0,
#   "scale_embedding": false,
#   "tie_word_embeddings": false,
#   "torch_dtype": "float32",
#   "transformers_version": "4.46.1",
#   "use_cache": true,
#   "use_fused_lm_heads": true,
#   "vocab_size": 1088
# }
# Loaded the voice encoder model on cuda in 0.07 seconds.
# ✅ Indic-Parler-TTS loaded successfully (male Urdu voice: Rohit)

# %%
from google.colab import userdata
try:
    hf_token = userdata.get("HF_TOKEN")
    print("✅ HF token loaded from Colab secrets")
except Exception:
    hf_token = None
    print("⚠️  HF_TOKEN not found in secrets — proceeding without token (may fail for gated datasets)")
# Out:
# ✅ HF token loaded from Colab secrets

# %%
from datasets import load_dataset

# ── 3. Literary / Storytelling style (60 samples, Male, Urdu) ──
print("‹‹ Loading Literary (BOOK) Male Samples (Goal: 60) ...")

ds_book_stream = load_dataset(
    "humairawan/UrduSpeech",
    data_dir="Urdu",
    split="train",
    token=hf_token,
    streaming=True,
)

book_male_samples = []
count = 0

for sample in ds_book_stream:
    count += 1
    style = str(sample.get("style", "")).strip().upper()
    gender = str(sample.get("gender", "")).strip().capitalize()

    if style == "BOOK" and gender == "Male":
        book_male_samples.append(sample)

    # Provide visual feedback every 1000 samples scanned
    if count % 1000 == 0:
        print(f"  Checked {count} samples... Found {len(book_male_samples)} matches so far.")

    if len(book_male_samples) >= 60:
        break

    # Safety break to avoid infinite loops if data is missing
    if count > 50000:
        print("  Stopping search: scanned 50,000 samples without finding 60 matches.")
        break

print(f"  Collected {len(book_male_samples)} BOOK Male samples after scanning {count} total entries.")
results_book = run_evaluation("humair_book_male", book_male_samples, text_key="text", limit=60)
# Out:
# ‹‹ Loading Literary (BOOK) Male Samples (Goal: 60) ...
# Resolving data files:   0%|          | 0/56 [00:00<?, ?it/s]
#   Checked 1000 samples... Found 0 matches so far.
#   Checked 2000 samples... Found 0 matches so far.
#   Checked 3000 samples... Found 0 matches so far.
#   Checked 4000 samples... Found 0 matches so far.
#   Checked 5000 samples... Found 0 matches so far.
#   Checked 6000 samples... Found 0 matches so far.
#   Checked 7000 samples... Found 0 matches so far.
#   Checked 8000 samples... Found 0 matches so far.
#   Checked 9000 samples... Found 0 matches so far.
#   Checked 10000 samples... Found 0 matches so far.
#   Checked 11000 samples... Found 0 matches so far.
#   Checked 12000 samples... Found 0 matches so far.
#   Checked 13000 samples... Found 21 matches so far.
#   Collected 60 BOOK Male samples after scanning 13677 total entries.
#   [01/60] sim=0.8320 gender=Male text=یا یہ طلسم ہے کہ اگر پھٹکری او...
#   [02/60] sim=0.8337 gender=Male text=میں جان و دل سے اُسے چاہتی تھی...
#   [03/60] sim=0.7983 gender=Male text=سب آدمی اپنے اپنے عہدوں پر مست...
#   [04/60] sim=0.7509 gender=Male text=تب انہوں نے فرمایا کہ مرتضیٰ ر...
#   [05/60] sim=0.7439 gender=Male text=تم سخاوت کا بوجھ نہیں اٹھا سکت...
#   [06/60] sim=0.7911 gender=Male text=سوائے اِس بات کے زبان سے کچھ ن...
#   [07/60] sim=0.8239 gender=Male text=آگے چوکی پر ڈونگے کٹورے، بمعِ ...
#   [08/60] sim=0.7871 gender=Male text=اور پھر ایک بار گئی، عاجز کو ی...
#   [09/60] sim=0.7272 gender=Male text=سچ مچ یہ تماشا ہوا جیسے چودھوی...
#   [10/60] sim=0.7566 gender=Male text=جب یہ احوال ناامیدی کا سنا، ای...
#   [11/60] sim=0.7341 gender=Male text=غرض بہتری خاک چھانی لیکن اُس گ...
#   [12/60] sim=0.7673 gender=Male text=نظر کی مجال نہ تھی جو اس کے جم...
#   [13/60] sim=0.7332 gender=Male text=بھلا ایک زخم اور بھی لگا، میں ...
#   [14/60] sim=0.6818 gender=Male text=میں ابتدا سے کہتا ہوں، تا انتہ...
#   [15/60] sim=0.8061 gender=Male text=ہرچند انہوں نے میرے غائب ہونے ...
#   [16/60] sim=0.8138 gender=Male text=بارے خدا خدا کر کے صبح جب نزدی...
#   [17/60] sim=0.7738 gender=Male text=یہ دونوں کی باتیں حاتم نے سنیں...
#   [18/60] sim=0.6736 gender=Male text=میرے طرف دھیان نہ کیا۔...
#   [19/60] sim=0.7871 gender=Male text=موافقِ قدر و منزلت کے ہر ایک ک...
#   [20/60] sim=0.8240 gender=Male text=تو نے جان و مال سے میری خاطر ک...
#   [21/60] sim=0.7987 gender=Male text=جب نو فل کے روبرو لے گئے تو اس...
#   [22/60] sim=0.7846 gender=Male text=سن کر مسکرایا اور بولا "مناسب ...
#   [23/60] sim=0.7691 gender=Male text=میں نے بہت منت کی اور ہاتھ جوڑ...
#   [24/60] sim=0.7633 gender=Male text=ساری رات دروازے گھروں کے بند ن...
#   [25/60] sim=0.8420 gender=Male text=طاقت بدن میں مطلق نہ رہی،اپاہج...
#   [26/60] sim=0.7903 gender=Male text=حکم کرتے ہی تھوڑے دنوں میں ایس...
#   [27/60] sim=0.7931 gender=Male text=میں اپنے دل کو ہر چند سنبھالتی...
#   [28/60] sim=0.8322 gender=Male text=اُس مرد آدمی نے کہا، یہ وہی کم...
#   [29/60] sim=0.7854 gender=Male text=راہ میں جو کچھ مصیبتیں قسمت می...
#   [30/60] sim=0.7593 gender=Male text=تمام دن جیسے روزہ دار شام ہونے...
#   [31/60] sim=0.8005 gender=Male text=غرض جس کے گھر میں اتنی دولت او...
#   [32/60] sim=0.7325 gender=Male text=اس واسطے کہ آدمی کا دل خدا کا ...
#   [33/60] sim=0.8025 gender=Male text=پچھلے پہر ڈاکا آیا، جو کچھ مال...
#   [34/60] sim=0.7471 gender=Male text=تونے مجھے نہال کیا، لیکن مردوں...
#   [35/60] sim=0.8198 gender=Male text=غرض، قسمت کی خوبی اس ملک کی تھ...
#   [36/60] sim=0.8116 gender=Male text= آدمان باتوں سے سوائے اُس خوج ...
#   [37/60] sim=0.6327 gender=Male text=دو ہیں طبیب آ کر جمع ہوئے۔...
#   [38/60] sim=0.6792 gender=Male text=دیر نہ کیجیے، سچ ہے معشوق بن ک...
#   [39/60] sim=0.7842 gender=Male text=نبضِ قارورہ دیکھ کر بہت غور کی...
#   [40/60] sim=0.7922 gender=Male text=جس کی یہ قدرت اور سکت ہو، سکی ...
#   [41/60] sim=0.7468 gender=Male text=پس عبادت بھی اس روز کام نہ آئے...
#   [42/60] sim=0.6564 gender=Male text=فی الفور قلمدان آگے رکھ دیا۔...
#   [43/60] sim=0.7832 gender=Male text=ہر دم اُس کی خاطر داری کرتی، آ...
#   [44/60] sim=0.7793 gender=Male text=اندر سے گھوراکر بولے، اس وقت د...
#   [45/60] sim=0.7741 gender=Male text=ندہڑک بول اٹھا کہ اب اِس طور ک...
#   [46/60] sim=0.6984 gender=Male text=یہ کہاوت ہے۔...
#   [47/60] sim=0.7999 gender=Male text=ایک روز ایک مصاحب دانانہ کہ خو...
#   [48/60] sim=0.8211 gender=Male text=ہمارے ہاتھ حاتم کا ہے؟ کوئی آو...
#   [49/60] sim=0.6832 gender=Male text=اس کا عذاب میرے نام لکھا جائے ...
#   [50/60] sim=0.7390 gender=Male text=میں نے سارا احوال مول تول کا ا...
#   [51/60] sim=0.7788 gender=Male text=میں نے معلوم کیا کہ اس احمق نے...
#   [52/60] sim=0.6145 gender=Male text=فقیر اس کے دیکھنے سے ڈر گیا۔...
#   [53/60] sim=0.6539 gender=Male text=چندے بیکاری گزری۔...
#   [54/60] sim=0.8462 gender=Male text=جب تھوڑی سی رات باقی رہی، بادش...
#   [55/60] sim=0.7123 gender=Male text=میں حیران ہوا لیکن اپنا گھر جا...
#   [56/60] sim=0.7691 gender=Male text=ہر ایک سے پوچھتا پھرتا تھا کہ ...
#   [57/60] sim=0.7368 gender=Male text=اتنے عرصے میں یہ سب تیاری کیوں...
#   [58/60] sim=0.6042 gender=Male text=آدمی اناج کا کیڑا ہے۔...
#   [59/60] sim=0.7965 gender=Male text=یہ کہہ کر اسی بے ہوشی کے عالم ...
#   [60/60] sim=0.7932 gender=Male text=کیا جانیں یہ دیو ہیں یا غول بی...
#
# ✅ humair_book_male: 60/60 samples evaluated

# %%
# ── 2. Formal / Wiki (30 samples, Male, Urdu) ──
print("\n‹‹ Loading Formal (WIKI) Male Samples (Goal: 30) ...")
# Re-initializing stream to ensure fresh traversal
ds_wiki_stream = load_dataset(
    "humairawan/UrduSpeech",
    data_dir="Urdu",
    split="train",
    token=hf_token,
    streaming=True,
)

wiki_male_samples = []
count = 0
for sample in ds_wiki_stream:
    count += 1
    style = str(sample.get("style", "")).strip().upper()
    gender = str(sample.get("gender", "")).strip().capitalize()

    if style == "WIKI" and gender == "Male":
        wiki_male_samples.append(sample)

    if count % 1000 == 0:
        print(f"  Checked {count} samples... Found {len(wiki_male_samples)} matches so far.")

    if len(wiki_male_samples) >= 30:
        break

    if count > 50000:
        print("  Stopping search: scanned 50,000 samples.")
        break

print(f"  Collected {len(wiki_male_samples)} WIKI Male samples after scanning {count} total entries.")
results_wiki = run_evaluation("humair_wiki_male", wiki_male_samples, text_key="text", limit=30)
# Out:
# ‹‹ Loading Formal (WIKI) Male Samples (Goal: 30) ...
# Resolving data files:   0%|          | 0/56 [00:00<?, ?it/s]
#   Checked 1000 samples... Found 0 matches so far.
#   Checked 2000 samples... Found 0 matches so far.
#   Checked 3000 samples... Found 0 matches so far.
#   Checked 4000 samples... Found 0 matches so far.
#   Checked 5000 samples... Found 0 matches so far.
#   Checked 6000 samples... Found 0 matches so far.
#   Checked 7000 samples... Found 0 matches so far.
#   Checked 8000 samples... Found 0 matches so far.
#   Checked 9000 samples... Found 0 matches so far.
#   Checked 10000 samples... Found 0 matches so far.
#   Checked 11000 samples... Found 0 matches so far.
#   Checked 12000 samples... Found 0 matches so far.
#   Collected 30 WIKI Male samples after scanning 12691 total entries.
#   [01/30] sim=0.8113 gender=Male text=آشوب چشم کی شناخت آنکھ کی جھلی...
#   [02/30] sim=0.8237 gender=Male text=جَبہَۃُ الاَکْراد شام کی خانہ ...
#   [03/30] sim=0.7878 gender=Male text=ایسا لگتا ہے کہ یہ نام میدانی ...
#   [04/30] sim=0.7845 gender=Male text=اس رکاوٹ سے نمٹنے کے لیے، حکوم...
#   [05/30] sim=0.8484 gender=Male text=سری وینکٹیشورا نیشنل پارک بھار...
#   [06/30] sim=0.7971 gender=Male text=مرزا ابو الفضل حاجی علی شیرازی...
#   [07/30] sim=0.8100 gender=Male text=شائستہ خان نے علاقے سے پرتگالی...
#   [08/30] sim=0.7230 gender=Male text=بلیک آؤٹ کے دوران سائٹ پر جانے...
#   [09/30] sim=0.7858 gender=Male text=غزوۂ اُحد کے بعد فتحِ مکہ تک ج...
#   [10/30] sim=0.8291 gender=Male text=آخر کار بھوت بھی کھڑکھڑاہٹ کے ...
#   [11/30] sim=0.8149 gender=Male text=گھریلو طور پر ہندوستان کا زیاد...
#   [12/30] sim=0.8274 gender=Male text=قرآن مجید اسلام کا اصل الاصول ...
#   [13/30] sim=0.7812 gender=Male text=سنہ دو ہزار نو عیسوی میں انہیں...
#   [14/30] sim=0.7308 gender=Male text=حضرت ابو درداء رضی اللہ تعالیٰ...
#   [15/30] sim=0.8078 gender=Male text=فلائیٹ لیفٹیننٹ غلام مرتضٰی مل...
#   [16/30] sim=0.7655 gender=Male text=زؤچوان کاؤنٹی لاطینی چین کا ای...
#   [17/30] sim=0.7949 gender=Male text=اس مسلئہ سے بآسانی یہ کلیہ اخذ...
#   [18/30] sim=0.7671 gender=Male text=ہرش اور پُلکیشن کے درمیان جنگ ...
#   [19/30] sim=0.8205 gender=Male text=ایکالینن کا مرکز جھیل کُروس یر...
#   [20/30] sim=0.8154 gender=Male text=کشیارا کو دریائے کالنی کے نام ...
#   [21/30] sim=0.8170 gender=Male text=عبد الالہ بن علی عربی عبد الإل...
#   [22/30] sim=0.8076 gender=Male text=کنڑ ادب کے تین جواہر آدی کَوی...
#   [23/30] sim=0.8112 gender=Male text=بنگلورو کے بانی کیمپے گوڈا نے ...
#   [24/30] sim=0.8106 gender=Male text=اجناس کی بڑھتی ہوئی قیمتیں، بے...
#   [25/30] sim=0.7313 gender=Male text=خشک سالی بھی نہیں سردی ہی پڑتی...
#   [26/30] sim=0.7773 gender=Male text=جینوم کی مدد سے افزائش نسل کے ...
#   [27/30] sim=0.7547 gender=Male text=مکندرا ہلز نیشنل پارک کوہِسْتا...
#   [28/30] sim=0.7398 gender=Male text=اتّر پردیش ہریانہ گجرات بہار م...
#   [29/30] sim=0.7084 gender=Male text=شہدائے ھفت تیر میٹرو اسٹیشن...
#   [30/30] sim=0.8515 gender=Male text=کالج کیمپس کے قریب کفایتی تھرف...
#
# ✅ humair_wiki_male: 30/30 samples evaluated

# %%
# ── 1. Conversational (60 samples, Male, Urdu) ──
print("‹‹ Loading Conversational Male Samples (Goal: 60) ...")
ds_stream = load_dataset(
    "humairawan/UrduSpeech",
    data_dir="Urdu",
    split="train",
    token=hf_token,
    streaming=True,
)

conv_male_samples = []
count = 0
for sample in ds_stream:
    count += 1
    style = str(sample.get("style", "")).strip().upper()
    gender = str(sample.get("gender", "")).strip().capitalize()

    if style == "CONV" and gender == "Male":
        conv_male_samples.append(sample)

    if count % 1000 == 0:
        print(f"  Checked {count} samples... Found {len(conv_male_samples)} matches so far.")

    if len(conv_male_samples) >= 60:
        break

    if count > 50000:
        print("  Stopping search: scanned 50,000 samples.")
        break

print(f"  Collected {len(conv_male_samples)} CONV Male samples after scanning {count} total entries.")
results_conv = run_evaluation("humair_conv_male", conv_male_samples, text_key="text", limit=60)
# Out:
# ‹‹ Loading Conversational Male Samples (Goal: 60) ...
# Resolving data files:   0%|          | 0/56 [00:00<?, ?it/s]
#   Checked 1000 samples... Found 0 matches so far.
#   Checked 2000 samples... Found 0 matches so far.
#   Checked 3000 samples... Found 0 matches so far.
#   Checked 4000 samples... Found 0 matches so far.
#   Checked 5000 samples... Found 0 matches so far.
#   Checked 6000 samples... Found 0 matches so far.
#   Checked 7000 samples... Found 0 matches so far.
#   Checked 8000 samples... Found 0 matches so far.
#   Checked 9000 samples... Found 0 matches so far.
#   Checked 10000 samples... Found 0 matches so far.
#   Checked 11000 samples... Found 0 matches so far.
#   Checked 12000 samples... Found 0 matches so far.
#   Collected 60 CONV Male samples after scanning 12900 total entries.
#   [01/60] sim=0.7336 gender=Male text=گوا کی یہ تہہ دار میٹھی چیز ہن...
#   [02/60] sim=0.7299 gender=Male text=آئیے دیکھتے ہیں کہ حالات ٹھیک ...
#   [03/60] sim=0.6657 gender=Male text=میں واقعی اس کی تعریف کرتا ہوں...
#   [04/60] sim=0.7736 gender=Male text=اس کے اوقات کیا ہیں؟...
#   [05/60] sim=0.6566 gender=Male text=پھر ملتے ہیں۔...
#   [06/60] sim=0.8109 gender=Male text=ذاتی تفصیلات جیسے رابطے اور رہ...
#   [07/60] sim=0.7639 gender=Male text=آپ نے حقیقت میں ہمارا ایک بڑا ...
#   [08/60] sim=0.7505 gender=Male text=فن آرٹ آن لائن آرٹ کلاس کو فن ...
#   [09/60] sim=0.7286 gender=Male text=ہے نا! وہ تو زبردست تھا۔...
#   [10/60] sim=0.7894 gender=Male text=یہ پی ڈی ایف فارمیٹ میں جاری ک...
#   [11/60] sim=0.7452 gender=Male text=دہرادون میں ہمارا سنٹر رائے پو...
#   [12/60] sim=0.7742 gender=Male text=جی ہاں، وہ بہر حال مہیا کیا جا...
#   [13/60] sim=0.6451 gender=Male text=میں آپ کی پریشانی کو سمجھتا ہو...
#   [14/60] sim=0.7291 gender=Male text=یہ مندروں کا شہر ہے تو شاید آپ...
#   [15/60] sim=0.7650 gender=Male text=کوئی شخص اپنے تفریحی مشغلوں سے...
#   [16/60] sim=0.7484 gender=Male text=سنجیدگی سے، یہ ضروری ہے کہ ہم ...
#   [17/60] sim=0.7682 gender=Male text=لہذا ہم جو بھی پڑھتے ہیں میں ا...
#   [18/60] sim=0.7895 gender=Male text=یہاں تک کہ میرے جسمانی عمل اور...
#   [19/60] sim=0.7123 gender=Male text=میوزک اور ڈانس کا کیا؟...
#   [20/60] sim=0.6009 gender=Male text=ٹھیک ہے۔ یہ کافی مہنگا ہے۔...
#   [21/60] sim=0.8235 gender=Male text=متبادل کے طور پر، آپ ڈیبٹ یا ک...
#   [22/60] sim=0.7774 gender=Male text=سر، تو آپ چاہتے ہیں کہ میں اعل...
#   [23/60] sim=0.6525 gender=Male text=اس کی کون سی مختلف اقسام ہیں؟...
#   [24/60] sim=0.7708 gender=Male text=علاوہ ازیں، ہندوستانی جغرافیہ ...
#   [25/60] sim=0.7040 gender=Male text=براہ مہربانی بتائیے۔...
#   [26/60] sim=0.7513 gender=Male text=کیا آپ کے لیے یہ ٹھیک رہے گا؟...
#   [27/60] sim=0.7795 gender=Male text=براہ کرم مجھے بتائیے کہ آپ کس ...
#   [28/60] sim=0.7333 gender=Male text=جی ہاں، ہم کس طرح آپ کی مدد کر...
#   [29/60] sim=0.7228 gender=Male text=اگر آپ کو کسی مدد کی ضرورت ہو ...
#   [30/60] sim=0.7023 gender=Male text=اوہ، سمجھ رہا ہوں۔...
#   [31/60] sim=0.7492 gender=Male text=لیکن وہ مجھے شادی کر کے رخصت ک...
#   [32/60] sim=0.6939 gender=Male text=بی بی ایف ایس کی ماتحتی میں کت...
#   [33/60] sim=0.8261 gender=Male text=ارے کرش!...
#   [34/60] sim=0.7020 gender=Male text=سر، میں ایسا عہدہ چاہتی ہوں جس...
#   [35/60] sim=0.7848 gender=Male text=میں نے سنا ہے کہ اس کا ڈیزائن ...
#   [36/60] sim=0.7529 gender=Male text=میں خود بھی سوچتا رہتا ہوں، کہ...
#   [37/60] sim=0.8326 gender=Male text=ہر چیز کا الگ ذائقہ ہوتا۔...
#   [38/60] sim=0.8309 gender=Male text=ویسے کیا ہم سب صرف جنک نہیں ہی...
#   [39/60] sim=0.7110 gender=Male text=واقعی نہیں، شاید ہم مل کر گھوم...
#   [40/60] sim=0.7674 gender=Male text=کیا آپ میرے کچھ سوالات کا جواب...
#   [41/60] sim=0.7222 gender=Male text=مجھے بتاؤ، وویک، آپ کا مسئلہ ک...
#   [42/60] sim=0.7120 gender=Male text=میں ویشنو دیوی مندر کی زیارت ک...
#   [43/60] sim=0.7588 gender=Male text=یہ واقعی ایک تجربہ ہوتا ہے۔...
#   [44/60] sim=0.7138 gender=Male text=یہاں تک کہ یہ بھی زیادہ نہیں ہ...
#   [45/60] sim=0.7658 gender=Male text=براہ کرم مجھے بتائیے آپ کو کیا...
#   [46/60] sim=0.6534 gender=Male text=ایس بی آئی انٹرنیٹ بینکنگ فراہ...
#   [47/60] sim=0.6912 gender=Male text=جی ایچ آئی نگر، فلاں فلاں اسٹر...
#   [48/60] sim=0.6654 gender=Male text=کیا یہ بات کرنے کا صحیح وقت ہے...
#   [49/60] sim=0.6939 gender=Male text=جی ہاں، ضرور، میم۔...
#   [50/60] sim=0.7824 gender=Male text=ہاں، سر، میں تقریبا ہر چیز پر ...
#   [51/60] sim=0.6653 gender=Male text=اس نے کتنے سال تک کھیلا؟...
#   [52/60] sim=0.7947 gender=Male text=میں نے فارم بھرے، پوسٹ کے ذریع...
#   [53/60] sim=0.6802 gender=Male text=یہ میرے لیے خوشی کی بات ہے،  ج...
#   [54/60] sim=0.4459 gender=Male text=کیا حال ہے، یار؟...
#   [55/60] sim=0.7867 gender=Male text=تھراپی آپ کے لیے مددگار ثابت ہ...
#   [56/60] sim=0.6813 gender=Male text=ہم آپ کے لیے کیا کر سکتے ہیں؟...
#   [57/60] sim=0.8206 gender=Male text=بالکل! اب آپ کو اتنا کرنا ہے ک...
#   [58/60] sim=0.7660 gender=Male text=وہاں پر ساؤتھ انڈیا کے مسالا د...
#   [59/60] sim=0.7207 gender=Male text=بالکل، مجھے جلدی نہیں ہے۔...
#   [60/60] sim=0.6518 gender=Male text=ٹھیک ہے جناب۔...
#
# ✅ humair_conv_male: 60/60 samples evaluated

# %%
import zipfile
import os
import pandas as pd

# ── Define domains and their results ────────────────────────────────────────
domains = [
    ("book", results_book, "mushra_humair_book_male"),
    ("wiki", results_wiki, "mushra_humair_wiki_male"),
    ("conv", results_conv, "mushra_humair_conv_male")
]

# ── Generate separate CSVs and ZIPs for each domain ─────────────────────────
for domain_name, results, folder_name in domains:
    # 1. Create and save individual CSV
    df_domain = pd.DataFrame(results)
    df_domain["dataset"] = f"humair_{domain_name}"

    # Select relevant columns
    valid_cols = ["dataset", "sample_id", "urdu_text", "audio_duration_sec", "ref_gen_similarity"]
    df_domain = df_domain[valid_cols]

    csv_filename = f"humair_{domain_name}_evaluation_results_parler_tts.csv"
    df_domain.to_csv(csv_filename, index=False, encoding="utf-8-sig")
    print(f"✅ Saved CSV: {csv_filename}")

    # 2. Create individual ZIP
    zip_filename = f"mushra_humair_{domain_name}.zip"
    if os.path.exists(folder_name):
        with zipfile.ZipFile(zip_filename, "w") as zf:
            for root, _, files in os.walk(folder_name):
                for file in files:
                    zf.write(os.path.join(root, file))
        print(f"✅ Created ZIP: {zip_filename}")
    else:
        print(f"☑ Folder {folder_name} not found, skipping ZIP.")

# ── Summary Display ──────────────────────────────────────────────────────────
all_df = pd.concat([pd.DataFrame(r).assign(dataset=n) for n, r, _ in domains])
stats = all_df.groupby("dataset").agg(
    mean_gen_sim=("ref_gen_similarity", "mean"),
    std_gen_sim=("ref_gen_similarity", "std"),
    count=("sample_id", "count")
)
display(stats)
# Out:
# ✅ Saved CSV: humair_book_evaluation_results.csv
# ✅ Created ZIP: mushra_humair_book.zip
# ✅ Saved CSV: humair_wiki_evaluation_results.csv
# ✅ Created ZIP: mushra_humair_wiki.zip
# ✅ Saved CSV: humair_conv_evaluation_results.csv
# ✅ Created ZIP: mushra_humair_conv.zip
#          mean_gen_sim  std_gen_sim  count
# dataset
# book         0.762445     0.057202     60
# conv         0.732015     0.064800     60
# wiki         0.791187     0.037068     30
